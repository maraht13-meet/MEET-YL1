# %%
import csv

# %%
f = open('cig.csv','rb') 
reader = csv.reader(f)
tar_content = []
nicotine_content = []
weight = []
carbon_monoxide_content = [] 
for row in reader:
    a = row[0]
    b = a.replace("\t"," ")
    c = b.split()
    d = c[1::]
    e = map(float,d) 
    tar_content.append(e[0])
    nicotine_content.append(e[1])
    weight.append(e[2])
    carbon_monoxide_content.append(e[3])

    
print tar_content
print nicotine_content
print weight
print carbon_monoxide_content
   
    
f.close()
# Out:
# [14.1, 16.0, 29.8, 8.0, 4.1, 15.0, 8.8, 12.4, 16.6, 14.9, 13.7, 15.1, 7.8, 11.4, 9.0, 1.0, 17.0, 12.8, 15.8, 4.5, 14.5, 7.3, 8.6, 15.2, 12.0]
# [0.86, 1.06, 2.03, 0.67, 0.4, 1.04, 0.76, 0.95, 1.12, 1.02, 1.01, 0.9, 0.57, 0.78, 0.74, 0.13, 1.26, 1.08, 0.96, 0.42, 1.01, 0.61, 0.69, 1.02, 0.82]
# [0.9853, 1.0938, 1.165, 0.928, 0.9462, 0.8885, 1.0267, 0.9225, 0.9372, 0.8858, 0.9643, 0.9316, 0.9705, 1.124, 0.8517, 0.7851, 0.9186, 1.0395, 0.9573, 0.9106, 1.007, 0.9806, 0.9693, 0.9496, 1.1184]
# [13.6, 16.6, 23.5, 10.2, 5.4, 15.0, 9.0, 12.3, 16.3, 15.4, 13.0, 14.4, 10.0, 10.2, 9.5, 1.5, 18.5, 12.6, 17.5, 4.9, 15.9, 8.5, 10.6, 13.9, 14.9]

# %%
from pylab import *
fig = plt.figure()                                                                                                
m = fig.add_subplot(111)
m.set_title('Tar Content and Nicotine Content')
m.set_xlabel('Tar Content')
m.set_ylabel('Nicotine Content')
m.scatter(tar_content, nicotine_content)
fig.savefig("tar_content_and_with_titles.png")

# %%
from pylab import *
fig = plt.figure()
n = fig.add_subplot(111)
n.set_title('Weight and Carbon Monoxide Content')
n.set_xlabel('Weight')
n.set_ylabel('Carbon Monoxide Content')
n.scatter(weight, carbon_monoxide_content)
fig.savefig("cig.csv_with_titles.png")
